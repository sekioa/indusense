# %%
print("Hello Jupyter")
# Out:
# Hello Jupyter

# %% [markdown]
# # Data ingestion
# - Read a csv file first using pandas
# - Extract features from the dataset
# > Column numbers, row numbers, max min from numeric values
